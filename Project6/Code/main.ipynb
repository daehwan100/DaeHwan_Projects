# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r /content/drive/MyDrive/Track-Anything/requirements.txt

# %%
# gradio 오류 시
# !pip install --upgrade gradio==3.48

# %%
# segment-anything model 다운로드 안되었을 시
# !pip install 'git+https://github.com/facebookresearch/segment-anything.git'

# %%
# %cd /content/drive/MyDrive/MIA_TRACKING_7조
# %run MIA_tracking_excute.py
# Out:
# /content/drive/MyDrive/MIA_TRACKING_7조
# Initializing BaseSegmenter to cuda:0
# Hyperparameters read from the model weights: C^k=64, C^v=512, C^h=64
# Single object mode: False
# /content/drive/MyDrive/MIA_TRACKING_7조/MIA_tracking_excute.py:382: GradioUnusedKwargWarning: You have unused kwarg parameters in Row, please remove them: {'scale': 0.4}
#   with gr.Row(scale=0.4):
# /content/drive/MyDrive/MIA_TRACKING_7조/MIA_tracking_excute.py:383: GradioUnusedKwargWarning: You have unused kwarg parameters in Video, please remove them: {'autosize': True}
#   video_input = gr.Video(autosize=True)
# /content/drive/MyDrive/MIA_TRACKING_7조/MIA_tracking_excute.py:403: GradioDeprecationWarning: The `style` method is deprecated. Please set these arguments in the constructor instead.
#   clear_button_click = gr.Button(value="Clear points", interactive=True, visible=False).style(height=160)
# ...
